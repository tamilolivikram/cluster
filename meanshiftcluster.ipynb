# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_Customers.csv")

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=dataset.iloc[:,[3,4]].values

# %%
import scipy.cluster.hierarchy as sch

# %%
dendrogram=sch.dendrogram(sch.linkage(x,method="ward"))
plt.title('dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %%
pip install --upgrade scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-learn in e:\anacoda3\envs\hopeai\lib\site-packages (1.0.2)
# Requirement already satisfied: joblib>=0.11 in e:\anacoda3\envs\hopeai\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: scipy>=1.1.0 in e:\anacoda3\envs\hopeai\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in e:\anacoda3\envs\hopeai\lib\site-packages (from scikit-learn) (1.17.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\anacoda3\envs\hopeai\lib\site-packages (from scikit-learn) (3.1.0)

# %%
from sklearn.cluster import MeanShift
clusmodel = MeanShift(bandwidth=10)
label=clusmodel.fit_predict(x)

# %%
supervised=pd.DataFrame(dataset)
supervised['cluster_group']=label
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster_group
# 0                9
# 1                6
# 2                7
# 3                6
# 4                9
# ..             ...
# 195             16
# 196             20
# 197             16
# 198             19
# 199             18
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False)
